# %%
# %pwd
# Out:
# '/content'

# %%
# !nvidia-smi
# Out:
# Fri Dec 10 03:27:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/BoostingMonocularDepth"
# Out:
# /content/drive/.shortcut-targets-by-id/1uhVaAqp6WMmug9565jnv_t9h7zfHHvxI/BoostingMonocularDepth

# %%
# connect to google drive in colab first
# %cd "/content/drive/MyDrive/Project/Github/BoostingMonocularDepth"
# Out:
# /content/drive/MyDrive/Project/Github/BoostingMonocularDepth

# %%
# download weights of merge network

# !wget https://sfu.ca/~yagiz/CVPR21/latest_net_G.pth
#!gdown https://drive.google.com/u/0/uc?id=1cU2y-kMbt0Sf00Ns4CN2oO9qPJ8BensP&export=download

# Downloading merge model weights
#!mkdir -p /content/BoostingMonocularDepth/pix2pix/checkpoints/mergemodel/
#!mv latest_net_G.pth /content/BoostingMonocularDepth/pix2pix/checkpoints/mergemodel/

# %%
# 2 demo images
# !python run.py --Final --data_dir ./inputs --output_dir  ./outputs --depthNet 0 --colorize_results
# Out:
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=True, data_dir='./inputs', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./o1', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: True                          	[default: False]
#                 crop_size: 672
#                  data_dir: ./inputs                      	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# ibims1 dataset run
# !python run.py --Final --data_dir ./dataset_prepare/ibims1/rgb --output_dir ./outputs_ibims --depthNet 0
# Out:
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/ibims1/rgb', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_ibims', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/ibims1/rgb  	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# DIODE dataset
# !python run.py --Final --data_dir ./dataset_prepare/DIODE/rgb --output_dir ./outputs_diode --depthNet 0
# Out:
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/DIODE/rgb', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_diode', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/DIODE/rgb   	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# %pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1uhVaAqp6WMmug9565jnv_t9h7zfHHvxI/BoostingMonocularDepth'

# %%
# necessary package for midas v3
# !pip install timm

# midas v3 with diode dataset
# !python run.py --Final --data_dir ./dataset_prepare/DIODE/rgb --output_dir ./outputs_diode_midasV3 --depthNet 3
# Out:
# ...
#      |████████████████████████████████| 376 kB 5.1 MB/s
# ...
# device: cpu
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/DIODE/rgb', depthNet=3, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_diode_midasV3', output_resolution=1, pix2pixsize=1024, savelowhigh=0, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/DIODE/rgb   	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 3                             	[default: None]
#                 direction: AtoB
# ...

# %%
# necessary package for midas v3
# !pip install timm

# midas v3 with ibims1 dataset
# !python run.py --Final --data_dir ./dataset_prepare/ibims1/rgb --output_dir ./outputs_ibims1_midasV3 --depthNet 3
# Out:
# ...
#      |████████████████████████████████| 376 kB 13.1 MB/s
# ...
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/ibims1/rgb', depthNet=3, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_ibims1_midasV3', output_resolution=1, pix2pixsize=1024, savelowhigh=0, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/ibims1/rgb  	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 3                             	[default: None]
#                 direction: AtoB
# ...

# %%
# keep colab active for 12h max
while True:
  pass
