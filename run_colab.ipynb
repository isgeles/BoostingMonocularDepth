# %%
# %pwd
# Out:
# '/content'

# %%
# !nvidia-smi
# Out:
# Sun Nov 28 00:13:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# connect to google drive in colab first
# %cd "/content/drive/MyDrive/TUGraz/9. Semester UW/SYDE671/Project/Github/BoostingMonocularDepth"
# Out:
# /content/drive/MyDrive/TUGraz/9. Semester UW/SYDE671/Project/Github/BoostingMonocularDepth

# %%
# !python run.py --Final --data_dir ./inputs --output_dir  ./outputs_ --depthNet 0 --colorize_results
# Out:
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=True, data_dir='./inputs', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./o1', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: True                          	[default: False]
#                 crop_size: 672
#                  data_dir: ./inputs                      	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# ibims1 dataset run
# !python run.py --Final --data_dir ./dataset_prepare/ibims1/rgb --output_dir ./outputs_ibims --depthNet 0
# Out:
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/ibims1/rgb', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_ibims', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/ibims1/rgb  	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# !python run.py --Final --data_dir ./dataset_prepare/ibims1/rgb --output_dir ./outputs_ibims --depthNet 0
# Out:
# device: cpu
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='./dataset_prepare/ibims1/rgb', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='./outputs_ibims', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: ./dataset_prepare/ibims1/rgb  	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
# ...

# %%
# keep colab active for 12h max
while True:
  pass

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/SYDE_Project/BoostingMonocularDepth/dataset_prepare/midas"
# Out:
# /content/drive/MyDrive/Colab Notebooks/SYDE_Project/BoostingMonocularDepth/dataset_prepare/midas

# %%
# !python run.py --res 384 --input_dir "../ibims1/rgb" --output_dir "../ibims1/whole_low_est"
# Out:
# initialize
# device: cuda
# Loading weights:  model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
#   processing ../ibims1/rgb/corridor_01.png (1/101)
#   processing ../ibims1/rgb/corridor_02.png (2/101)
#   processing ../ibims1/rgb/corridor_06.png (3/101)
#   processing ../ibims1/rgb/corridor_04.png (4/101)
#   processing ../ibims1/rgb/corridor_05.png (5/101)
#   processing ../ibims1/rgb/corridor_03.png (6/101)
#   processing ../ibims1/rgb/corridor_07.png (7/101)
#   processing ../ibims1/rgb/corridor_08.png (8/101)
#   processing ../ibims1/rgb/corridor_09.png (9/101)
#   processing ../ibims1/rgb/corridor_10.png (10/101)
#   processing ../ibims1/rgb/factory_02.png (11/101)
#   processing ../ibims1/rgb/factory_01.png (12/101)
#   processing ../ibims1/rgb/factory_03.png (13/101)
#   processing ../ibims1/rgb/factory_04.png (14/101)
#   processing ../ibims1/rgb/factory_05.png (15/101)
# ...

# %%
# !python run.py --res 672 --input_dir "../ibims1/rgb" --output_dir "../ibims1/whole_high_est"
# Out:
# initialize
# device: cuda
# Loading weights:  model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
#   processing ../ibims1/rgb/corridor_01.png (1/101)
#   processing ../ibims1/rgb/corridor_02.png (2/101)
#   processing ../ibims1/rgb/corridor_06.png (3/101)
#   processing ../ibims1/rgb/corridor_04.png (4/101)
#   processing ../ibims1/rgb/corridor_05.png (5/101)
#   processing ../ibims1/rgb/corridor_03.png (6/101)
#   processing ../ibims1/rgb/corridor_07.png (7/101)
#   processing ../ibims1/rgb/corridor_08.png (8/101)
#   processing ../ibims1/rgb/corridor_09.png (9/101)
#   processing ../ibims1/rgb/corridor_10.png (10/101)
#   processing ../ibims1/rgb/factory_02.png (11/101)
#   processing ../ibims1/rgb/factory_01.png (12/101)
#   processing ../ibims1/rgb/factory_03.png (13/101)
#   processing ../ibims1/rgb/factory_04.png (14/101)
#   processing ../ibims1/rgb/factory_05.png (15/101)
# ...
