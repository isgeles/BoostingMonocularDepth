# %%
# %pwd
# Out:
# '/content'

# %%
# !nvidia-smi
# Out:
# Thu Nov 25 23:23:55 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   71C    P8    37W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd "/content/drive/MyDrive/TUGraz/9. Semester UW/SYDE671/Project/Github/BoostingMonocularDepth/dataset_prepare/midas"
# Out:
# /content/drive/MyDrive/TUGraz/9. Semester UW/SYDE671/Project/Github/BoostingMonocularDepth/dataset_prepare/midas

# %%
# !python run.py --res 640 --input_dir "../ibims1/rgb" --output_dir "../ibims1/orig_estimate"
# Out:
# initialize
# device: cuda
# Loading weights:  model.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/archive/main.zip" to /root/.cache/torch/hub/main.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:05<00:00, 62.5MB/s]
# start processing
#   processing ../ibims1/rgb/corridor_02.png (1/100)
#   processing ../ibims1/rgb/corridor_01.png (2/100)
#   processing ../ibims1/rgb/corridor_06.png (3/100)
#   processing ../ibims1/rgb/corridor_04.png (4/100)
#   processing ../ibims1/rgb/corridor_05.png (5/100)
#   processing ../ibims1/rgb/corridor_03.png (6/100)
#   processing ../ibims1/rgb/corridor_09.png (7/100)
#   processing ../ibims1/rgb/corridor_08.png (8/100)
#   processing ../ibims1/rgb/corridor_07.png (9/100)
#   processing ../ibims1/rgb/corridor_10.png (10/100)
#   processing ../ibims1/rgb/factory_02.png (11/100)
# ...

# %%
 # !python run.py --res 672 --input_dir "../ibims1/rgb" --output_dir "../ibims1/whole_high_est"
# Out:
# initialize
# device: cuda
# Loading weights:  model.pt
# Using cache found in /root/.cache/torch/hub/facebookresearch_WSL-Images_main
# start processing
#   processing ../ibims1/rgb/corridor_01.png (1/101)
#   processing ../ibims1/rgb/corridor_02.png (2/101)
#   processing ../ibims1/rgb/corridor_06.png (3/101)
#   processing ../ibims1/rgb/corridor_04.png (4/101)
#   processing ../ibims1/rgb/corridor_05.png (5/101)
#   processing ../ibims1/rgb/corridor_03.png (6/101)
#   processing ../ibims1/rgb/corridor_07.png (7/101)
#   processing ../ibims1/rgb/corridor_08.png (8/101)
#   processing ../ibims1/rgb/corridor_09.png (9/101)
#   processing ../ibims1/rgb/corridor_10.png (10/101)
#   processing ../ibims1/rgb/factory_02.png (11/101)
#   processing ../ibims1/rgb/factory_01.png (12/101)
#   processing ../ibims1/rgb/factory_03.png (13/101)
#   processing ../ibims1/rgb/factory_04.png (14/101)
#   processing ../ibims1/rgb/factory_05.png (15/101)
# ...
